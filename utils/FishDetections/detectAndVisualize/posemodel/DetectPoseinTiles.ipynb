# %%
import cv2
import numpy as np

def tile_frame(frame, tile_size=320, overlap=0.4):
    stride = int(tile_size * (1 - overlap))
    tiles = []
    tile_positions = []  # To track the original position of each tile in the frame
    
    for y in range(0, frame.shape[0] - tile_size + 1, stride):
        for x in range(0, frame.shape[1] - tile_size + 1, stride):
            tile = frame[y:y+tile_size, x:x+tile_size]
            tiles.append(tile)
            tile_positions.append((x, y))
            
    return tiles, tile_positions

# %%
from ultralytics import YOLO

# Load the YOLO model
model = YOLO('/Users/apaula/Library/CloudStorage/GoogleDrive-elysiacristata@gmail.com/My Drive/datasets/runs/pose/train9/weights/best.pt')

# %%
def detect_pose_in_tile(tile, model, confidence_threshold=0.3):
    results = model(tile)
    detections = []

    # Accessing the first (and presumably only) Results object
    results_object = results[0]

    # Extracting bounding boxes and their confidence scores from 'data' attribute
    if hasattr(results_object, 'boxes') and results_object.boxes is not None:
        for i, box_data in enumerate(results_object.boxes.data):
            # box_data format: [x_min, y_min, x_max, y_max, conf, cls]
            conf = box_data[4].item()  # Convert tensor to Python scalar
            if conf > confidence_threshold:
                detection = {
                    'bbox': box_data[:4].cpu().numpy(),  # Convert bbox tensor to numpy array
                    'confidence': conf,
                    'class': box_data[5].item()  # Class of the detection
                }
                # Add keypoints if available
                if hasattr(results_object, 'keypoints') and results_object.keypoints is not None and len(results_object.keypoints.data) > i:
                    kp_data = results_object.keypoints.data[i]
                    detection['keypoints'] = {
                        'points': kp_data[:, :2].cpu().numpy(),  # Keypoint coordinates
                        'confidence': kp_data[:, 2].cpu().numpy()  # Keypoint confidences
                    }
                detections.append(detection)

    return detections

# %%
def visualize_detections_on_tile(tile, detections):
    for detection in detections:
        # Draw bounding box
        cv2.rectangle(tile, (int(detection['bbox'][0]), int(detection['bbox'][1])), 
                      (int(detection['bbox'][2]), int(detection['bbox'][3])), (0, 255, 0), 2)
        # For keypoints visualization, adjust based on your keypoints data structure
        # e.g., cv2.drawKeypoints(tile, keypoints, ...)
    
    cv2.imshow('Detection', tile)
    cv2.waitKey(0)

# %%
import os
import cv2

def draw_detections_and_save(tile, detections, save_dir, tile_index):
    """
    Draw detections on a tile and save the result to disk.
    
    Parameters:
    - tile: The image tile to draw detections on.
    - detections: A list of detections where each detection is a dictionary
      containing 'bbox' (bounding box as [xmin, ymin, xmax, ymax]) and 'confidence'.
    - save_dir: Directory to save the output images.
    - tile_index: Index of the tile to create a unique filename.
    """
    # Ensure the save directory exists
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    
    # Draw detections on the tile
    for detection in detections:
        bbox = detection['bbox']
        cv2.rectangle(tile, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (0, 255, 0), 2)
        confidence = detection.get('confidence', 0)
        cv2.putText(tile, f'{confidence:.2f}', (int(bbox[0]), int(bbox[1]-5)), cv2.FONT_HERSHEY_SIMPLEX, 
                    0.5, (255, 255, 255), 2)
    
    # Save the tile with detections drawn on it
    save_path = os.path.join(save_dir, f'tile_{tile_index}.jpg')
    cv2.imwrite(save_path, tile)

# %%
def process_tiles_and_save_detections(tiles, model, save_dir='detected_tiles'):
    """
    Process each tile for pose detection, draw the detections, and save the results.
    
    Parameters:
    - tiles: List of image tiles to process.
    - model: The loaded pose detection model.
    - save_dir: Directory to save the output images with detections.
    """
    for i, tile in enumerate(tiles):
        # Assuming your detection function returns a list of detections for the tile
        detections = detect_pose_in_tile(tile, model)
        draw_detections_and_save(tile, detections, save_dir, i)

# %%
# Example call to process tiles and save detections
    # Load the image
image_path = '/Volumes/T7-August/sample_frame.jpg'
frame = cv2.imread(image_path)
tiles, tile_positions = tile_frame(frame)  # Unpack both tiles and their positions
model = YOLO('/Users/apaula/Library/CloudStorage/GoogleDrive-elysiacristata@gmail.com/My Drive/datasets/runs/pose/train9/weights/best.pt')  # Load your model
process_tiles_and_save_detections(tiles, model)
# Out:
# 0: 320x320 (no detections), 125.2ms
# Speed: 1.5ms preprocess, 125.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 124.5ms
# Speed: 0.5ms preprocess, 124.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 122.1ms
# Speed: 0.6ms preprocess, 122.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 116.9ms
# Speed: 0.6ms preprocess, 116.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 5 fishs, 117.9ms
# Speed: 0.5ms preprocess, 117.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 18 fishs, 117.2ms
# Speed: 0.4ms preprocess, 117.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 22 fishs, 120.8ms
# Speed: 0.5ms preprocess, 120.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 19 fishs, 130.8ms
# Speed: 0.5ms preprocess, 130.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 127.3ms
# Speed: 0.5ms preprocess, 127.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 6 fishs, 139.1ms
# Speed: 0.8ms preprocess, 139.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 6 fishs, 131.0ms
# Speed: 0.6ms preprocess, 131.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 7 fishs, 125.0ms
# Speed: 0.6ms preprocess, 125.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 123.7ms
# Speed: 0.6ms preprocess, 123.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 6 fishs, 119.0ms
# Speed: 0.5ms preprocess, 119.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 113.5ms
# Speed: 0.5ms preprocess, 113.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 7 fishs, 115.7ms
# Speed: 0.4ms preprocess, 115.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 8 fishs, 117.5ms
# Speed: 0.5ms preprocess, 117.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 10 fishs, 118.2ms
# Speed: 0.5ms preprocess, 118.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 5 fishs, 115.7ms
# Speed: 0.5ms preprocess, 115.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 1 fish, 119.0ms
# Speed: 0.5ms preprocess, 119.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 2 fishs, 117.2ms
# Speed: 0.5ms preprocess, 117.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 4 fishs, 113.6ms
# Speed: 0.4ms preprocess, 113.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 116.8ms
# Speed: 0.6ms preprocess, 116.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 2 fishs, 118.8ms
# Speed: 0.5ms preprocess, 118.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 10 fishs, 114.9ms
# Speed: 0.4ms preprocess, 114.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 24 fishs, 115.9ms
# Speed: 0.5ms preprocess, 115.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 27 fishs, 114.4ms
# Speed: 0.5ms preprocess, 114.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 20 fishs, 117.5ms
# Speed: 0.4ms preprocess, 117.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 14 fishs, 108.3ms
# Speed: 0.5ms preprocess, 108.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 7 fishs, 112.4ms
# Speed: 0.5ms preprocess, 112.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 7 fishs, 110.7ms
# Speed: 0.4ms preprocess, 110.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 16 fishs, 111.5ms
# Speed: 0.4ms preprocess, 111.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 14 fishs, 118.5ms
# Speed: 0.4ms preprocess, 118.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 120.6ms
# Speed: 0.4ms preprocess, 120.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 7 fishs, 115.3ms
# Speed: 0.5ms preprocess, 115.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 6 fishs, 112.6ms
# Speed: 0.5ms preprocess, 112.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 8 fishs, 114.7ms
# Speed: 0.4ms preprocess, 114.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 14 fishs, 114.3ms
# Speed: 0.5ms preprocess, 114.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 21 fishs, 118.8ms
# Speed: 0.4ms preprocess, 118.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 36 fishs, 126.1ms
# Speed: 0.4ms preprocess, 126.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 126.5ms
# Speed: 1.5ms preprocess, 126.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 7 fishs, 120.7ms
# Speed: 0.5ms preprocess, 120.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 121.7ms
# Speed: 0.5ms preprocess, 121.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 15 fishs, 117.2ms
# Speed: 0.5ms preprocess, 117.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 29 fishs, 118.1ms
# Speed: 0.6ms preprocess, 118.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 13 fishs, 121.0ms
# Speed: 0.5ms preprocess, 121.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 21 fishs, 111.7ms
# Speed: 0.5ms preprocess, 111.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 13 fishs, 114.7ms
# Speed: 0.4ms preprocess, 114.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 118.2ms
# Speed: 0.4ms preprocess, 118.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 6 fishs, 119.0ms
# Speed: 0.4ms preprocess, 119.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 120.3ms
# Speed: 0.5ms preprocess, 120.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 22 fishs, 118.3ms
# Speed: 0.6ms preprocess, 118.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 25 fishs, 119.0ms
# Speed: 0.4ms preprocess, 119.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 19 fishs, 113.8ms
# Speed: 0.5ms preprocess, 113.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 16 fishs, 117.9ms
# Speed: 0.5ms preprocess, 117.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 13 fishs, 114.2ms
# Speed: 0.6ms preprocess, 114.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 26 fishs, 118.3ms
# Speed: 0.6ms preprocess, 118.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 23 fishs, 114.7ms
# Speed: 0.6ms preprocess, 114.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 26 fishs, 120.0ms
# Speed: 0.5ms preprocess, 120.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 14 fishs, 113.0ms
# Speed: 0.5ms preprocess, 113.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 122.4ms
# Speed: 0.5ms preprocess, 122.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 15 fishs, 113.5ms
# Speed: 0.4ms preprocess, 113.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 19 fishs, 120.7ms
# Speed: 0.5ms preprocess, 120.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 22 fishs, 121.0ms
# Speed: 0.5ms preprocess, 121.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 26 fishs, 110.7ms
# Speed: 0.6ms preprocess, 110.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 20 fishs, 111.9ms
# Speed: 0.4ms preprocess, 111.9ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 13 fishs, 121.9ms
# Speed: 0.6ms preprocess, 121.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 18 fishs, 117.7ms
# Speed: 0.4ms preprocess, 117.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 16 fishs, 114.1ms
# Speed: 0.4ms preprocess, 114.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 11 fishs, 119.1ms
# Speed: 0.4ms preprocess, 119.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 125.5ms
# Speed: 0.4ms preprocess, 125.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 120.4ms
# Speed: 0.5ms preprocess, 120.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 125.3ms
# Speed: 0.4ms preprocess, 125.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 116.3ms
# Speed: 0.5ms preprocess, 116.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 22 fishs, 114.9ms
# Speed: 0.5ms preprocess, 114.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 21 fishs, 115.8ms
# Speed: 0.5ms preprocess, 115.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 11 fishs, 118.9ms
# Speed: 0.5ms preprocess, 118.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 21 fishs, 124.3ms
# Speed: 0.5ms preprocess, 124.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 11 fishs, 126.3ms
# Speed: 0.5ms preprocess, 126.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 16 fishs, 117.2ms
# Speed: 0.4ms preprocess, 117.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 22 fishs, 127.3ms
# Speed: 0.5ms preprocess, 127.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 24 fishs, 124.2ms
# Speed: 0.4ms preprocess, 124.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 37 fishs, 112.8ms
# Speed: 0.5ms preprocess, 112.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 38 fishs, 121.0ms
# Speed: 0.6ms preprocess, 121.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 34 fishs, 123.5ms
# Speed: 0.5ms preprocess, 123.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 25 fishs, 120.8ms
# Speed: 0.5ms preprocess, 120.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 18 fishs, 117.8ms
# Speed: 0.5ms preprocess, 117.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 21 fishs, 115.4ms
# Speed: 0.6ms preprocess, 115.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 20 fishs, 117.0ms
# Speed: 0.4ms preprocess, 117.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 23 fishs, 121.5ms
# Speed: 0.5ms preprocess, 121.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 15 fishs, 117.0ms
# Speed: 0.5ms preprocess, 117.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 13 fishs, 127.5ms
# Speed: 0.6ms preprocess, 127.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 13 fishs, 118.4ms
# Speed: 0.6ms preprocess, 118.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 17 fishs, 123.8ms
# Speed: 0.5ms preprocess, 123.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 18 fishs, 124.4ms
# Speed: 0.5ms preprocess, 124.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 123.6ms
# Speed: 0.6ms preprocess, 123.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 10 fishs, 136.5ms
# Speed: 0.4ms preprocess, 136.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 123.4ms
# Speed: 0.4ms preprocess, 123.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 8 fishs, 127.4ms
# Speed: 0.5ms preprocess, 127.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 23 fishs, 128.7ms
# Speed: 0.4ms preprocess, 128.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 42 fishs, 124.0ms
# Speed: 0.5ms preprocess, 124.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 34 fishs, 118.8ms
# Speed: 0.5ms preprocess, 118.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 29 fishs, 125.0ms
# Speed: 0.6ms preprocess, 125.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 19 fishs, 141.3ms
# Speed: 0.6ms preprocess, 141.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 19 fishs, 122.3ms
# Speed: 0.5ms preprocess, 122.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 16 fishs, 124.9ms
# Speed: 0.6ms preprocess, 124.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 18 fishs, 121.8ms
# Speed: 0.4ms preprocess, 121.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 24 fishs, 124.0ms
# Speed: 0.4ms preprocess, 124.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 27 fishs, 128.6ms
# Speed: 0.5ms preprocess, 128.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 19 fishs, 115.8ms
# Speed: 0.5ms preprocess, 115.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 37 fishs, 116.7ms
# Speed: 0.5ms preprocess, 116.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 20 fishs, 129.9ms
# Speed: 0.6ms preprocess, 129.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 13 fishs, 118.2ms
# Speed: 0.6ms preprocess, 118.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 28 fishs, 125.2ms
# Speed: 0.5ms preprocess, 125.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 6 fishs, 123.7ms
# Speed: 0.6ms preprocess, 123.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 8 fishs, 122.2ms
# Speed: 0.5ms preprocess, 122.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 10 fishs, 125.7ms
# Speed: 0.5ms preprocess, 125.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 19 fishs, 121.9ms
# Speed: 0.5ms preprocess, 121.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 18 fishs, 122.2ms
# Speed: 0.7ms preprocess, 122.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 28 fishs, 131.9ms
# Speed: 0.6ms preprocess, 131.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 30 fishs, 129.1ms
# Speed: 0.4ms preprocess, 129.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 41 fishs, 124.7ms
# Speed: 0.5ms preprocess, 124.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 25 fishs, 123.3ms
# Speed: 0.6ms preprocess, 123.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 21 fishs, 122.5ms
# Speed: 0.4ms preprocess, 122.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 18 fishs, 123.5ms
# Speed: 0.5ms preprocess, 123.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 26 fishs, 122.4ms
# Speed: 0.6ms preprocess, 122.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 16 fishs, 124.0ms
# Speed: 0.5ms preprocess, 124.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 27 fishs, 119.2ms
# Speed: 0.4ms preprocess, 119.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 23 fishs, 129.3ms
# Speed: 0.4ms preprocess, 129.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 25 fishs, 125.9ms
# Speed: 0.4ms preprocess, 125.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 16 fishs, 116.8ms
# Speed: 0.4ms preprocess, 116.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 18 fishs, 121.8ms
# Speed: 0.4ms preprocess, 121.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 20 fishs, 115.7ms
# Speed: 0.6ms preprocess, 115.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 119.8ms
# Speed: 0.6ms preprocess, 119.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 124.3ms
# Speed: 0.5ms preprocess, 124.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 8 fishs, 118.2ms
# Speed: 0.5ms preprocess, 118.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 27 fishs, 123.6ms
# Speed: 0.5ms preprocess, 123.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 22 fishs, 117.9ms
# Speed: 0.5ms preprocess, 117.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 37 fishs, 126.6ms
# Speed: 0.5ms preprocess, 126.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 23 fishs, 120.4ms
# Speed: 0.5ms preprocess, 120.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 11 fishs, 127.9ms
# Speed: 0.5ms preprocess, 127.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 2 fishs, 126.3ms
# Speed: 0.5ms preprocess, 126.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 5 fishs, 122.7ms
# Speed: 0.5ms preprocess, 122.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 119.1ms
# Speed: 0.5ms preprocess, 119.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 121.9ms
# Speed: 0.7ms preprocess, 121.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 19 fishs, 116.0ms
# Speed: 0.5ms preprocess, 116.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 16 fishs, 120.1ms
# Speed: 0.5ms preprocess, 120.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 10 fishs, 116.3ms
# Speed: 0.5ms preprocess, 116.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 17 fishs, 123.0ms
# Speed: 0.5ms preprocess, 123.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 13 fishs, 123.2ms
# Speed: 0.6ms preprocess, 123.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 15 fishs, 126.0ms
# Speed: 0.5ms preprocess, 126.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 123.2ms
# Speed: 0.5ms preprocess, 123.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 124.3ms
# Speed: 0.6ms preprocess, 124.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 123.7ms
# Speed: 0.6ms preprocess, 123.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 125.9ms
# Speed: 0.5ms preprocess, 125.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 3 fishs, 141.4ms
# Speed: 0.4ms preprocess, 141.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 5 fishs, 122.0ms
# Speed: 0.4ms preprocess, 122.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 116.3ms
# Speed: 0.5ms preprocess, 116.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 9 fishs, 115.8ms
# Speed: 0.4ms preprocess, 115.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 115.5ms
# Speed: 0.6ms preprocess, 115.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 124.6ms
# Speed: 0.5ms preprocess, 124.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.1ms
# Speed: 0.5ms preprocess, 120.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 1 fish, 122.2ms
# Speed: 0.6ms preprocess, 122.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 10 fishs, 125.9ms
# Speed: 0.6ms preprocess, 125.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 23 fishs, 120.8ms
# Speed: 0.4ms preprocess, 120.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 22 fishs, 117.3ms
# Speed: 0.4ms preprocess, 117.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 120.6ms
# Speed: 0.6ms preprocess, 120.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 8 fishs, 123.8ms
# Speed: 0.5ms preprocess, 123.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 1 fish, 115.5ms
# Speed: 0.5ms preprocess, 115.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 8 fishs, 126.2ms
# Speed: 0.4ms preprocess, 126.2ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 17 fishs, 126.5ms
# Speed: 0.4ms preprocess, 126.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 127.7ms
# Speed: 0.7ms preprocess, 127.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 125.4ms
# Speed: 0.4ms preprocess, 125.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 114.5ms
# Speed: 0.4ms preprocess, 114.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 115.2ms
# Speed: 0.5ms preprocess, 115.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 111.5ms
# Speed: 0.4ms preprocess, 111.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 4 fishs, 119.6ms
# Speed: 0.4ms preprocess, 119.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 7 fishs, 124.4ms
# Speed: 0.5ms preprocess, 124.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 5 fishs, 119.7ms
# Speed: 0.5ms preprocess, 119.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 1 fish, 119.5ms
# Speed: 0.5ms preprocess, 119.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 113.9ms
# Speed: 0.5ms preprocess, 113.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 134.5ms
# Speed: 0.5ms preprocess, 134.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 5 fishs, 130.1ms
# Speed: 0.5ms preprocess, 130.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 23 fishs, 130.5ms
# Speed: 0.6ms preprocess, 130.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 22 fishs, 127.0ms
# Speed: 0.5ms preprocess, 127.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 15 fishs, 118.5ms
# Speed: 0.5ms preprocess, 118.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 6 fishs, 127.2ms
# Speed: 0.5ms preprocess, 127.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 5 fishs, 121.1ms
# Speed: 0.5ms preprocess, 121.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 7 fishs, 120.0ms
# Speed: 0.4ms preprocess, 120.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 10 fishs, 115.4ms
# Speed: 0.4ms preprocess, 115.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
