# %%
import cv2
import numpy as np

def tile_frame(frame, tile_size=320, overlap=0.4):
    stride = int(tile_size * (1 - overlap))
    tiles = []
    tile_positions = []  # To track the original position of each tile in the frame
    
    for y in range(0, frame.shape[0] - tile_size + 1, stride):
        for x in range(0, frame.shape[1] - tile_size + 1, stride):
            tile = frame[y:y+tile_size, x:x+tile_size]
            tiles.append(tile)
            tile_positions.append((x, y))
            
    return tiles, tile_positions

# %%
from ultralytics import YOLO

# Load the YOLO model
model = YOLO('/Users/apaula/Library/CloudStorage/GoogleDrive-elysiacristata@gmail.com/My Drive/datasets/runs/pose/train9/weights/best.pt')

# %%
def detect_pose_in_tile(tile, model, confidence_threshold=0.3, distance_range=(25, 100)):
    results = model(tile)
    detections = []

    # Accessing the first (and presumably only) Results object
    results_object = results[0]

    # Extracting bounding boxes and their confidence scores from 'data' attribute
    if hasattr(results_object, 'boxes') and results_object.boxes is not None:
        for i, box_data in enumerate(results_object.boxes.data):
            conf = box_data[4].item()  # Convert tensor to Python scalar
            if conf > confidence_threshold:
                detection = {
                    'bbox': box_data[:4].cpu().numpy(),  # Convert bbox tensor to numpy array
                    'confidence': conf,
                    'class': box_data[5].item()  # Class of the detection
                }

                # Add keypoints if available
                if hasattr(results_object, 'keypoints') and results_object.keypoints is not None and len(results_object.keypoints.data) > i:
                    kp_data = results_object.keypoints.data[i]
                    points = kp_data[:, :2].cpu().numpy()  # Keypoint coordinates

                    # Calculate distances between pairs of keypoints and apply filtering
                    if len(points) > 1:  # Ensure there are at least two points to form a pair
                        distances = np.linalg.norm(points[0] - points[1], axis=0)
                        if distance_range[0] <= distances <= distance_range[1]:
                            detection['keypoints'] = {
                                'points': points,
                                'confidence': kp_data[:, 2].cpu().numpy()  # Keypoint confidences
                            }

                detections.append(detection)

    return detections

# %%
def visualize_detections_on_tile(tile, detections):
    for detection in detections:
        # Draw bounding box
        cv2.rectangle(tile, (int(detection['bbox'][0]), int(detection['bbox'][1])), 
                      (int(detection['bbox'][2]), int(detection['bbox'][3])), (0, 255, 0), 2)
        # For keypoints visualization, adjust based on your keypoints data structure
        # e.g., cv2.drawKeypoints(tile, keypoints, ...)
    
    cv2.imshow('Detection', tile)
    cv2.waitKey(0)

# %%
import os
import cv2
import numpy as np

def draw_detections_and_save(tile, detections, save_dir, tile_index, draw_boxes=True):
    """
    Draw keypoints, lines between them with strong visibility, and optionally bounding boxes with reduced alpha on a tile and save the result to disk.
    
    Parameters:
    - tile: The image tile to draw detections on.
    - detections: A list of detections where each detection is a dictionary
      containing 'bbox' (bounding box as [xmin, ymin, xmax, ymax]), 'confidence',
      and optionally 'keypoints' with 'points' and 'confidence'.
    - save_dir: Directory to save the output images.
    - tile_index: Index of the tile to create a unique filename.
    - draw_boxes: Boolean to decide if bounding boxes should also be drawn.
    """
    # Ensure the save directory exists
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Create a copy of the tile to draw bounding boxes with reduced opacity
    if draw_boxes:
        overlay_boxes = tile.copy()

    # Create a copy of the tile to draw keypoints and lines with stronger opacity
    overlay_keypoints = tile.copy()

    # Draw detections on the tile
    for detection in detections:
        if draw_boxes:
            bbox = detection['bbox']
            cv2.rectangle(overlay_boxes, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (0, 255, 0), 2)
            confidence = detection.get('confidence', 0)
            cv2.putText(overlay_boxes, f'{confidence:.2f}', (int(bbox[0]), int(bbox[1]-5)), cv2.FONT_HERSHEY_SIMPLEX, 
                        0.5, (255, 255, 255), 2)

        if 'keypoints' in detection:
            keypoints = detection['keypoints']['points']
            # Assuming keypoints are paired
            for i in range(0, len(keypoints), 2):
                point1 = (int(keypoints[i][0]), int(keypoints[i][1]))
                point2 = (int(keypoints[i+1][0]), int(keypoints[i+1][1]))
                cv2.circle(overlay_keypoints, point1, 5, (255, 0, 0), -1)  # Draw keypoints in red
                cv2.circle(overlay_keypoints, point2, 5, (0, 0, 255), -1)  # Draw keypoints in blue
                cv2.line(overlay_keypoints, point1, point2, (0, 255, 255), 2)  # Strong yellow line

    # Blend overlays with the original image
    if draw_boxes:
        cv2.addWeighted(overlay_boxes, 0.2, tile, 0.8, 0, tile)  # Bounding boxes with reduced opacity
    cv2.addWeighted(overlay_keypoints, 0.8, tile, 0.2, 0, tile)  # Keypoints and lines with stronger opacity

    # Save the tile with detections drawn on it
    save_path = os.path.join(save_dir, f'tile_{tile_index}.jpg')
    cv2.imwrite(save_path, tile)

# %%
def process_tiles_and_save_detections(tiles, model, save_dir='detected_tiles'):
    """
    Process each tile for pose detection, draw the detections, and save the results.
    
    Parameters:
    - tiles: List of image tiles to process.
    - model: The loaded pose detection model.
    - save_dir: Directory to save the output images with detections.
    """
    for i, tile in enumerate(tiles):
        # Assuming your detection function returns a list of detections for the tile
        detections = detect_pose_in_tile(tile, model)
        draw_detections_and_save(tile, detections, save_dir, i)

# %%
# Example call to process tiles and save detections
    # Load the image
#image_path = '/Volumes/T7-August/sample_frame.jpg'
image_path = '/Users/apaula/src/SharkVideoAnalysis/20240219_184319_poseDetections/temp_frame.jpg'
frame = cv2.imread(image_path)
tiles, tile_positions = tile_frame(frame)  # Unpack both tiles and their positions
model = YOLO('/Users/apaula/Library/CloudStorage/GoogleDrive-elysiacristata@gmail.com/My Drive/datasets/runs/pose/train9/weights/best.pt')  # Load your model
process_tiles_and_save_detections(tiles, model)
# Out:
# 0: 320x320 (no detections), 133.2ms
# Speed: 2.4ms preprocess, 133.2ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.1ms
# Speed: 0.7ms preprocess, 120.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 118.9ms
# Speed: 0.5ms preprocess, 118.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 118.7ms
# Speed: 0.5ms preprocess, 118.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.8ms
# Speed: 0.5ms preprocess, 120.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 123.7ms
# Speed: 0.5ms preprocess, 123.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 119.3ms
# Speed: 0.5ms preprocess, 119.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 122.9ms
# Speed: 0.5ms preprocess, 122.9ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 119.5ms
# Speed: 0.6ms preprocess, 119.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 117.6ms
# Speed: 0.6ms preprocess, 117.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 119.5ms
# Speed: 0.5ms preprocess, 119.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 121.5ms
# Speed: 0.5ms preprocess, 121.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 114.8ms
# Speed: 0.5ms preprocess, 114.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.1ms
# Speed: 0.5ms preprocess, 120.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 118.3ms
# Speed: 0.5ms preprocess, 118.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 118.3ms
# Speed: 0.5ms preprocess, 118.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.8ms
# Speed: 0.5ms preprocess, 120.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 115.6ms
# Speed: 0.5ms preprocess, 115.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.4ms
# Speed: 0.5ms preprocess, 120.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 121.4ms
# Speed: 0.6ms preprocess, 121.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 115.9ms
# Speed: 0.5ms preprocess, 115.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 118.5ms
# Speed: 0.5ms preprocess, 118.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 118.1ms
# Speed: 0.5ms preprocess, 118.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 126.3ms
# Speed: 0.5ms preprocess, 126.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 123.4ms
# Speed: 0.5ms preprocess, 123.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 125.6ms
# Speed: 0.5ms preprocess, 125.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.3ms
# Speed: 0.6ms preprocess, 120.3ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 116.6ms
# Speed: 0.5ms preprocess, 116.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 144.9ms
# Speed: 0.5ms preprocess, 144.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.1ms
# Speed: 0.5ms preprocess, 120.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 121.2ms
# Speed: 0.5ms preprocess, 121.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.2ms
# Speed: 0.5ms preprocess, 120.2ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 117.8ms
# Speed: 0.5ms preprocess, 117.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 117.6ms
# Speed: 0.5ms preprocess, 117.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 119.7ms
# Speed: 0.6ms preprocess, 119.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 114.6ms
# Speed: 0.5ms preprocess, 114.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 115.5ms
# Speed: 0.5ms preprocess, 115.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 117.4ms
# Speed: 0.6ms preprocess, 117.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 16 fishs, 120.3ms
# Speed: 0.6ms preprocess, 120.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 16 fishs, 121.3ms
# Speed: 0.4ms preprocess, 121.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 12 fishs, 117.7ms
# Speed: 0.4ms preprocess, 117.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 17 fishs, 113.1ms
# Speed: 0.4ms preprocess, 113.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 10 fishs, 116.6ms
# Speed: 0.4ms preprocess, 116.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 5 fishs, 118.7ms
# Speed: 0.5ms preprocess, 118.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 1 fish, 116.9ms
# Speed: 0.5ms preprocess, 116.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 117.4ms
# Speed: 0.5ms preprocess, 117.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 118.5ms
# Speed: 0.5ms preprocess, 118.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 126.1ms
# Speed: 0.5ms preprocess, 126.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 118.7ms
# Speed: 0.5ms preprocess, 118.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 114.5ms
# Speed: 0.5ms preprocess, 114.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 125.7ms
# Speed: 0.6ms preprocess, 125.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 122.5ms
# Speed: 0.5ms preprocess, 122.5ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 122.5ms
# Speed: 0.6ms preprocess, 122.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 126.5ms
# Speed: 0.5ms preprocess, 126.5ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 140.5ms
# Speed: 0.5ms preprocess, 140.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 126.1ms
# Speed: 0.7ms preprocess, 126.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 1 fish, 127.7ms
# Speed: 0.5ms preprocess, 127.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 41 fishs, 129.3ms
# Speed: 0.6ms preprocess, 129.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 31 fishs, 122.8ms
# Speed: 0.5ms preprocess, 122.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 39 fishs, 121.3ms
# Speed: 0.5ms preprocess, 121.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 41 fishs, 123.4ms
# Speed: 0.6ms preprocess, 123.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 37 fishs, 124.6ms
# Speed: 0.5ms preprocess, 124.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 31 fishs, 120.7ms
# Speed: 0.4ms preprocess, 120.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 23 fishs, 124.6ms
# Speed: 0.5ms preprocess, 124.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 15 fishs, 118.9ms
# Speed: 0.5ms preprocess, 118.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 13 fishs, 123.5ms
# Speed: 0.5ms preprocess, 123.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 10 fishs, 120.9ms
# Speed: 0.5ms preprocess, 120.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 2 fishs, 116.9ms
# Speed: 0.4ms preprocess, 116.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 1 fish, 122.7ms
# Speed: 0.5ms preprocess, 122.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 117.6ms
# Speed: 0.5ms preprocess, 117.6ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 121.1ms
# Speed: 0.5ms preprocess, 121.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 119.2ms
# Speed: 0.5ms preprocess, 119.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.2ms
# Speed: 0.5ms preprocess, 120.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 1 fish, 124.1ms
# Speed: 0.6ms preprocess, 124.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 120.2ms
# Speed: 0.7ms preprocess, 120.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 1 fish, 118.6ms
# Speed: 0.5ms preprocess, 118.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 43 fishs, 121.5ms
# Speed: 0.6ms preprocess, 121.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 28 fishs, 118.7ms
# Speed: 0.6ms preprocess, 118.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 27 fishs, 119.3ms
# Speed: 0.5ms preprocess, 119.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 31 fishs, 123.2ms
# Speed: 0.5ms preprocess, 123.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 27 fishs, 148.2ms
# Speed: 0.5ms preprocess, 148.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 38 fishs, 128.3ms
# Speed: 0.5ms preprocess, 128.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 41 fishs, 127.0ms
# Speed: 0.5ms preprocess, 127.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 34 fishs, 121.0ms
# Speed: 0.5ms preprocess, 121.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 35 fishs, 125.9ms
# Speed: 0.6ms preprocess, 125.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 27 fishs, 122.2ms
# Speed: 0.5ms preprocess, 122.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 24 fishs, 133.3ms
# Speed: 0.6ms preprocess, 133.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 29 fishs, 121.6ms
# Speed: 0.5ms preprocess, 121.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 32 fishs, 123.6ms
# Speed: 0.5ms preprocess, 123.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 17 fishs, 124.3ms
# Speed: 0.5ms preprocess, 124.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 7 fishs, 123.3ms
# Speed: 0.4ms preprocess, 123.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 121.7ms
# Speed: 0.6ms preprocess, 121.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 125.9ms
# Speed: 0.5ms preprocess, 125.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 118.3ms
# Speed: 0.5ms preprocess, 118.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 124.6ms
# Speed: 0.5ms preprocess, 124.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 57 fishs, 130.9ms
# Speed: 0.6ms preprocess, 130.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 38 fishs, 122.6ms
# Speed: 0.8ms preprocess, 122.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 37 fishs, 127.7ms
# Speed: 0.5ms preprocess, 127.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 40 fishs, 124.4ms
# Speed: 0.5ms preprocess, 124.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 35 fishs, 125.7ms
# Speed: 0.7ms preprocess, 125.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 36 fishs, 122.7ms
# Speed: 0.7ms preprocess, 122.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 34 fishs, 123.8ms
# Speed: 0.4ms preprocess, 123.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 39 fishs, 123.6ms
# Speed: 0.5ms preprocess, 123.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 33 fishs, 124.0ms
# Speed: 0.7ms preprocess, 124.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 41 fishs, 124.3ms
# Speed: 0.5ms preprocess, 124.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 31 fishs, 152.0ms
# Speed: 0.5ms preprocess, 152.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 47 fishs, 132.5ms
# Speed: 0.8ms preprocess, 132.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 32 fishs, 124.1ms
# Speed: 0.4ms preprocess, 124.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 32 fishs, 121.4ms
# Speed: 0.6ms preprocess, 121.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 28 fishs, 132.6ms
# Speed: 0.5ms preprocess, 132.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 5 fishs, 121.6ms
# Speed: 0.5ms preprocess, 121.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 121.7ms
# Speed: 0.5ms preprocess, 121.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 121.7ms
# Speed: 0.5ms preprocess, 121.7ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 123.8ms
# Speed: 0.5ms preprocess, 123.8ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 47 fishs, 123.5ms
# Speed: 0.6ms preprocess, 123.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 42 fishs, 120.8ms
# Speed: 0.5ms preprocess, 120.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 33 fishs, 122.2ms
# Speed: 0.5ms preprocess, 122.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 35 fishs, 126.0ms
# Speed: 0.4ms preprocess, 126.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 35 fishs, 125.8ms
# Speed: 0.5ms preprocess, 125.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 39 fishs, 131.5ms
# Speed: 0.5ms preprocess, 131.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 46 fishs, 119.3ms
# Speed: 0.5ms preprocess, 119.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 47 fishs, 124.7ms
# Speed: 0.5ms preprocess, 124.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 44 fishs, 137.1ms
# Speed: 0.5ms preprocess, 137.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 45 fishs, 125.2ms
# Speed: 0.5ms preprocess, 125.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 33 fishs, 123.6ms
# Speed: 0.5ms preprocess, 123.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 36 fishs, 122.5ms
# Speed: 0.5ms preprocess, 122.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 38 fishs, 142.8ms
# Speed: 0.5ms preprocess, 142.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 29 fishs, 124.6ms
# Speed: 0.6ms preprocess, 124.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 45 fishs, 128.9ms
# Speed: 0.5ms preprocess, 128.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 21 fishs, 121.6ms
# Speed: 0.4ms preprocess, 121.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 134.1ms
# Speed: 0.6ms preprocess, 134.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 132.1ms
# Speed: 0.6ms preprocess, 132.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 161.9ms
# Speed: 0.6ms preprocess, 161.9ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 58 fishs, 123.6ms
# Speed: 0.6ms preprocess, 123.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 30 fishs, 123.5ms
# Speed: 0.6ms preprocess, 123.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 42 fishs, 121.7ms
# Speed: 0.5ms preprocess, 121.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 28 fishs, 131.6ms
# Speed: 0.5ms preprocess, 131.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 29 fishs, 140.7ms
# Speed: 0.6ms preprocess, 140.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 40 fishs, 135.7ms
# Speed: 0.4ms preprocess, 135.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 32 fishs, 124.1ms
# Speed: 0.5ms preprocess, 124.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 39 fishs, 129.2ms
# Speed: 0.5ms preprocess, 129.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 34 fishs, 125.8ms
# Speed: 0.5ms preprocess, 125.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 37 fishs, 119.4ms
# Speed: 0.4ms preprocess, 119.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 42 fishs, 124.8ms
# Speed: 0.6ms preprocess, 124.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 33 fishs, 123.7ms
# Speed: 0.5ms preprocess, 123.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 41 fishs, 135.9ms
# Speed: 0.6ms preprocess, 135.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 45 fishs, 140.4ms
# Speed: 0.6ms preprocess, 140.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 56 fishs, 141.1ms
# Speed: 0.5ms preprocess, 141.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 35 fishs, 125.0ms
# Speed: 0.5ms preprocess, 125.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 1 fish, 124.7ms
# Speed: 0.5ms preprocess, 124.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 119.1ms
# Speed: 0.5ms preprocess, 119.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 137.4ms
# Speed: 0.5ms preprocess, 137.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 60 fishs, 134.6ms
# Speed: 0.8ms preprocess, 134.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 31 fishs, 138.4ms
# Speed: 0.6ms preprocess, 138.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 42 fishs, 142.9ms
# Speed: 0.6ms preprocess, 142.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 50 fishs, 123.0ms
# Speed: 0.5ms preprocess, 123.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 41 fishs, 125.2ms
# Speed: 0.4ms preprocess, 125.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 40 fishs, 153.4ms
# Speed: 0.5ms preprocess, 153.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 33 fishs, 116.4ms
# Speed: 0.6ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 31 fishs, 119.7ms
# Speed: 0.4ms preprocess, 119.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 51 fishs, 129.5ms
# Speed: 0.5ms preprocess, 129.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 51 fishs, 140.7ms
# Speed: 0.8ms preprocess, 140.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 49 fishs, 140.0ms
# Speed: 0.6ms preprocess, 140.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 45 fishs, 135.3ms
# Speed: 0.5ms preprocess, 135.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 39 fishs, 145.8ms
# Speed: 1.0ms preprocess, 145.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 50 fishs, 138.7ms
# Speed: 0.6ms preprocess, 138.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 43 fishs, 147.1ms
# Speed: 0.8ms preprocess, 147.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 15 fishs, 142.9ms
# Speed: 0.5ms preprocess, 142.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 137.6ms
# Speed: 0.5ms preprocess, 137.6ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 139.1ms
# Speed: 0.6ms preprocess, 139.1ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 136.7ms
# Speed: 0.5ms preprocess, 136.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 57 fishs, 139.1ms
# Speed: 0.5ms preprocess, 139.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 45 fishs, 140.3ms
# Speed: 0.6ms preprocess, 140.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 45 fishs, 143.6ms
# Speed: 0.8ms preprocess, 143.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 41 fishs, 142.8ms
# Speed: 0.8ms preprocess, 142.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 36 fishs, 143.7ms
# Speed: 0.6ms preprocess, 143.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 32 fishs, 142.2ms
# Speed: 0.8ms preprocess, 142.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 46 fishs, 134.2ms
# Speed: 0.5ms preprocess, 134.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 52 fishs, 121.3ms
# Speed: 0.6ms preprocess, 121.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 45 fishs, 142.2ms
# Speed: 0.5ms preprocess, 142.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 47 fishs, 127.3ms
# Speed: 0.5ms preprocess, 127.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 34 fishs, 123.1ms
# Speed: 0.6ms preprocess, 123.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 24 fishs, 156.7ms
# Speed: 1.8ms preprocess, 156.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 29 fishs, 133.9ms
# Speed: 0.6ms preprocess, 133.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 26 fishs, 121.7ms
# Speed: 0.6ms preprocess, 121.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 13 fishs, 132.6ms
# Speed: 0.5ms preprocess, 132.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 7 fishs, 124.7ms
# Speed: 0.6ms preprocess, 124.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 129.8ms
# Speed: 0.5ms preprocess, 129.8ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 124.1ms
# Speed: 0.7ms preprocess, 124.1ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 130.3ms
# Speed: 0.5ms preprocess, 130.3ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 320)
